# %%
import requests
from bs4 import BeautifulSoup, NavigableString, Comment
import re
from urllib.parse import urljoin
from IPython.display import display, HTML

# %%
def extract_text_from_dom(soup, class_name):
    # Define a function to filter visible tags
    def tag_visible(element):
        if isinstance(element, Comment):
            return False
        if element.parent.name in ['style', 'script', 'head', 'title', 'meta', '[document]']:
            return False
        if class_name and class_name not in element.get('class', []):
            return False
        return True if isinstance(element, NavigableString) else tag_visible(element.parent)

    # Extract text from visible tags
    texts = soup.findAll(text=True)
    visible_texts = filter(tag_visible, texts)
    visible_text = u" ".join(t.strip() for t in visible_texts)

    # Split text into sentences using regular expressions
    sentences = re.split(r'(?<!\w\.\w.)(?<![A-Z][a-z]\.)(?<=\.|\?)\s', visible_text)
    return '\n'.join(sentences)

def extract_text_from_website(url, class_name=None, visited_urls=None, max_depth=1):
    # initialize visited_urls as an empty set if its not provided
    if visited_urls is None:
        visited_urls = set()

    # check if the URL has been visited to avoid infinite recursion
    if url in visited_urls:
        return ""

    # add the current URL to visited URLs
    visited_urls.add(url)

    extracted_text = ""
    try:
        # fetch the webpage content
        response = requests.get(url)
        response.raise_for_status()

        # parse the HTML content
        soup = BeautifulSoup(response.content, 'html.parser')

        # extract text from the current page
        extracted_text = extract_text_from_dom(soup, class_name)

        # find all links on the page
        links = soup.find_all('a', href=True, text=True)

        # extract text from linked pages recursively
        for link in links:
            subpage_url = link['href']
            # Convert relative links to absolute links
            subpage_url = urljoin(url, subpage_url)
            if subpage_url not in visited_urls and max_depth > 0:
                extracted_text += extract_text_from_website(subpage_url, class_name, visited_urls, max_depth - 1)
    except Exception as e:
        print(f"Error processing URL '{url}': {e}")

    return extracted_text

def extract_text_to_file(url, file_path, visited_urls=None, max_depth=1):
    # init visited_urls as an empty set if its not provided
    if visited_urls is None:
        visited_urls = set()

    # check if the URL has been visited to avoid infinite recursion
    if url in visited_urls:
        return ""

    # ddd the current URL to visited URLs
    visited_urls.add(url)

    extracted_text = ""
    try:
        # fetch the webpage content
        response = requests.get(url)
        response.raise_for_status()

        # parse the HTML content
        soup = BeautifulSoup(response.content, 'html.parser')

        # extract text from the current page
        extracted_text = extract_text_from_dom(soup)

        # find all links on the page
        links = soup.find_all('a', href=True, text=True)

        # extract text from linked pages recursively
        for link in links:
            subpage_url = link['href']
            # convert relative links to absolute links
            subpage_url = urljoin(url, subpage_url)
            if subpage_url not in visited_urls and max_depth > 0:
                extracted_text += extract_text_to_file(subpage_url, file_path, visited_urls, max_depth - 1)

    except Exception as e:
        print(f"Error processing URL '{url}': {e}")

    return extracted_text


def display_text_in_new_tab(text):
    html_content = f"""
    <script type="text/javascript">
        var newWindow = window.open("", "_blank");
        newWindow.document.write(`<pre>{text}</pre>`);
        newWindow.document.close();
    </script>
    """
    display(HTML(html_content))

# %%
# Example usage
url = "https://en.wikipedia.org/wiki/Snake"
class_name = "mw-content-text"  # specify the class name
extracted_text = extract_text_from_website(url)
display_text_in_new_tab(extracted_text)
file_path = "C:\\Users\\lukas\\OneDrive\\Desktop\\skola\\UKF\\bakalarka\\output\\outputWIKI.txt"
extract_text_to_file(url, file_path)
print(extracted_text)
# write the extracted_text to the file, had to use utf-8 for some characters
with open(file_path, 'w', encoding='utf-8') as f:
    f.write(extracted_text)
# Out:
# Error processing URL 'https://en.wikipedia.org/w/index.php?title=Jeffrey_L.Weinell&action=edit&redlink=1': 404 Client Error: Not Found for url: https://en.wikipedia.org/wiki/Jeffrey_L.Weinell
# Error processing URL 'https://en.wikipedia.org/w/index.php?title=Rafe_M.Brown&action=edit&redlink=1': 404 Client Error: Not Found for url: https://en.wikipedia.org/wiki/Rafe_M.Brown
# Error processing URL 'https://en.wikipedia.org/w/index.php?title=Monique_Bourgeois&action=edit&redlink=1': 404 Client Error: Not Found for url: https://en.wikipedia.org/wiki/Monique_Bourgeois
# Error processing URL 'https://en.wikipedia.org/w/index.php?title=Herndon_G._Dowling&action=edit&redlink=1': 404 Client Error: Not Found for url: https://en.wikipedia.org/wiki/Herndon_G._Dowling
# Error processing URL 'https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4438441': 403 Client Error: Forbidden for url: https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4438441/
# Error processing URL 'https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4372529': 403 Client Error: Forbidden for url: https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4372529/
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# Error processing URL 'https://www.science.org/content/article/fossils-oldest-known-snakes-unearthed': 403 Client Error: Forbidden for url: https://www.science.org/content/article/fossils-oldest-known-snakes-unearthed
# Error processing URL 'https://www.science.org': 403 Client Error: Forbidden for url: https://www.science.org/
# Error processing URL 'https://doi.org/10.1126%2Fscience.adh2449': 403 Client Error: Forbidden for url: https://www.science.org/doi/10.1126/science.adh2449
# Error processing URL 'http://www.wildlifenews.co.uk/articles2000/march/march2500a.htm': HTTPSConnectionPool(host='wildlifenews.co.uk', port=443): Max retries exceeded with url: /articles2000/march/march2500a.htm (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: certificate has expired (_ssl.c:1129)')))
# Error processing URL 'https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4681343': 403 Client Error: Forbidden for url: https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4681343/
# Error processing URL 'https://doi.org/10.1126%2Fsciadv.1500743': 403 Client Error: Forbidden for url: https://www.science.org/doi/10.1126/sciadv.1500743
# Error processing URL 'http://www.nature.com/nature/journal/v440/n7087/edsumm/e060420-11.html': 404 Client Error: Not Found for url: https://www.nature.com/nature/journal/v440/n7087/edsumm/e060420-11.html
# Error processing URL 'https://theconversation.com/extraordinary-skull-fossil-reveals-secrets-of-snake-evolution-127307': 403 Client Error: Forbidden for url: https://theconversation.com/extraordinary-skull-fossil-reveals-secrets-of-snake-evolution-127307
# Error processing URL 'https://doi.org/10.1126%2Fscience.aaa9208': 403 Client Error: Forbidden for url: https://www.science.org/doi/10.1126/science.aaa9208
# Error processing URL 'https://www.ncbi.nlm.nih.gov/pmc/articles/PMC1810015': 403 Client Error: Forbidden for url: https://www.ncbi.nlm.nih.gov/pmc/articles/PMC1810015/
# Error processing URL 'https://doi.org/10.1098%2Frsbl.2003.0151': 403 Client Error: Forbidden for url: https://royalsocietypublishing.org/doi/10.1098/rsbl.2003.0151
# Error processing URL 'https://doi.org/10.1111%2Fevo.13651': 403 Client Error: Forbidden for url: https://academic.oup.com/evolut/article/73/3/481/6727178
# Error processing URL 'https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5484524': 403 Client Error: Forbidden for url: https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5484524/
# Error processing URL 'http://www.aucklandmuseum.com/349/natural-history-questions': 404 Client Error: Not Found for url: https://www.aucklandmuseum.com/349/natural-history-questions
# Error processing URL 'https://doi.org/10.1017%2FS1477200007002290': 403 Client Error: Forbidden for url: https://www.tandfonline.com/doi/abs/10.1017/S1477200007002290
# Error processing URL 'http://www.anacondas.org/diss/disser.pdf': 503 Server Error: Service Unavailable for url: http://www.anacondas.org/diss/disser.pdf
# Error processing URL 'https://api.semanticscholar.org/CorpusID:198156987': 404 Client Error: Not Found for url: https://api.semanticscholar.org/CorpusID:198156987
# Error processing URL 'https://www.ncbi.nlm.nih.gov/pmc/articles/PMC9928108': 403 Client Error: Forbidden for url: https://www.ncbi.nlm.nih.gov/pmc/articles/PMC9928108/
# Error processing URL 'https://www.sciencedaily.com/releases/2016/08/160816182620.htm': 403 Client Error: Forbidden for url: https://www.sciencedaily.com/releases/2016/08/160816182620.htm
# Error processing URL 'https://academic.oup.com/mbe/article/33/10/2483/2925599': 403 Client Error: Forbidden for url: https://academic.oup.com/mbe/article/33/10/2483/2925599
# Error processing URL 'https://doi.org/10.1093%2Fmolbev%2Fmsw148': 403 Client Error: Forbidden for url: https://academic.oup.com/mbe/article-lookup/doi/10.1093/molbev/msw148
# Error processing URL 'https://doi.org/10.1093%2Fbeheco%2Fart058': 403 Client Error: Forbidden for url: https://academic.oup.com/beheco/article-lookup/doi/10.1093/beheco/art058
# Error processing URL 'https://www.jstor.org/stable/1564326': 420 Client Error: Enhance Your Calm for url: https://www.jstor.org/stable/1564326
# Error processing URL 'https://doi.org/10.2307%2F1564326': 420 Client Error: Enhance Your Calm for url: https://www.jstor.org/stable/1564326?origin=crossref
# Error processing URL 'http://www.sdgfp.info/Wildlife/Snakes/SnakeInfo.htm': 403 Client Error: Forbidden for url: https://serp.co/
# Error processing URL 'https://doi.org/10.7326%2F0003-4819-138-8-200304150-00016': 403 Client Error: Forbidden for url: https://www.acpjournals.org/doi/10.7326/0003-4819-138-8-200304150-00016
# Error processing URL 'http://www.physorg.com/news122123444.html': 400 Client Error: Bad request for url: http://www.physorg.com/news122123444.html
# Error processing URL 'http://jeb.biologists.org/cgi/reprint/54/2/349.pdf': 403 Client Error: Forbidden for url: http://jeb.biologists.org/cgi/reprint/54/2/349.pdf
# Error processing URL 'https://doi.org/10.1242%2Fjeb.54.2.349': 403 Client Error: Forbidden for url: https://journals.biologists.com/jeb/article/54/2/349/21718/Physiological-Basis-for-Detection-of-Sound-and
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# Error processing URL 'https://doi.org/10.1080%2F00222938400770131': 403 Client Error: Forbidden for url: https://www.tandfonline.com/doi/abs/10.1080/00222938400770131
# Error processing URL 'https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3760860': 403 Client Error: Forbidden for url: https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3760860/
# Error processing URL 'https://doi.org/10.1111%2Fbrv.12056': 403 Client Error: Forbidden for url: https://onlinelibrary.wiley.com/doi/10.1111/brv.12056
# Error processing URL 'https://doi.org/10.1093%2Ficb%2F27.1.5': 403 Client Error: Forbidden for url: https://academic.oup.com/icb/article-lookup/doi/10.1093/icb/27.1.5
# Error processing URL 'https://www.ias.ac.in/article/fulltext/secb/020/01/0001-0029': 403 Client Error: Forbidden for url: https://www.ias.ac.in/article/fulltext/secb/020/01/0001-0029
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# Error processing URL 'https://www.ncbi.nlm.nih.gov/pmc/articles/PMC9185726': 403 Client Error: Forbidden for url: https://www.ncbi.nlm.nih.gov/pmc/articles/PMC9185726/
# Error processing URL 'https://www.ncbi.nlm.nih.gov/pmc/articles/PMC9748774': 403 Client Error: Forbidden for url: https://www.ncbi.nlm.nih.gov/pmc/articles/PMC9748774/
# Error processing URL 'https://doi.org/10.1098%2Frspb.2022.1702': 403 Client Error: Forbidden for url: https://royalsocietypublishing.org/doi/10.1098/rspb.2022.1702
# Error processing URL 'https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3497136': 403 Client Error: Forbidden for url: https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3497136/
# Error processing URL 'https://doi.org/10.1098%2Frsbl.2012.0666': 403 Client Error: Forbidden for url: https://royalsocietypublishing.org/doi/10.1098/rsbl.2012.0666
# Error processing URL 'https://doi.org/10.1093%2Fjhered%2Fesr080': 403 Client Error: Forbidden for url: http://academic.oup.com/jhered/article/102/6/759/836740/Consecutive-Virgin-Births-in-the-New-World-Boid
# Error processing URL 'https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3394116': 403 Client Error: Forbidden for url: https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3394116/
# Error processing URL 'https://doi.org/10.2307%2F1440898': 420 Client Error: Enhance Your Calm for url: https://www.jstor.org/stable/1440898?origin=crossref
# Error processing URL 'https://www.jstor.org/stable/1440898': 420 Client Error: Enhance Your Calm for url: https://www.jstor.org/stable/1440898
# Error processing URL 'https://doi.org/10.1002%2Fdvg.23077': 403 Client Error: Forbidden for url: https://onlinelibrary.wiley.com/doi/10.1002/dvg.23077
# Error processing URL 'https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2375934': 403 Client Error: Forbidden for url: https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2375934/
# Error processing URL 'https://doi.org/10.1098%2Frsbl.2006.0600': 403 Client Error: Forbidden for url: https://royalsocietypublishing.org/doi/10.1098/rsbl.2006.0600
# Error processing URL 'https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3682911': 403 Client Error: Forbidden for url: https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3682911/
# Error processing URL 'https://doi.org/10.1242%2Fjeb.00790': 403 Client Error: Forbidden for url: https://journals.biologists.com/jeb/article/207/4/579/14994/The-thermogenesis-of-digestion-in-rattlesnakes
# Error processing URL 'https://doi.org/10.1242%2Fjeb.034447': 403 Client Error: Forbidden for url: https://journals.biologists.com/jeb/article/213/9/1521/10270/The-functional-morphology-of-hooding-in-cobras
# Error processing URL 'https://doi.org/10.1242%2Fjeb.01170': 403 Client Error: Forbidden for url: https://journals.biologists.com/jeb/article/207/20/3483/14911/The-buccal-buckle-the-functional-morphology-of
# Error processing URL 'https://doi.org/10.1242%2Fjeb.23.2.101': 403 Client Error: Forbidden for url: https://journals.biologists.com/jeb/article/23/2/101/12102/The-Mechanism-of-Locomotion-in-Snakes
# Error processing URL 'https://doi.org/10.2307%2F1441886': 420 Client Error: Enhance Your Calm for url: https://www.jstor.org/stable/1441886?origin=crossref
# Error processing URL 'https://www.jstor.org/stable/1441886': 420 Client Error: Enhance Your Calm for url: https://www.jstor.org/stable/1441886
# Error processing URL 'https://doi.org/10.1126%2Fscience.249.4968.524': 403 Client Error: Forbidden for url: https://www.science.org/doi/10.1126/science.249.4968.524
# Error processing URL 'https://doi.org/10.1242%2Fjeb.26.4.354': 403 Client Error: Forbidden for url: https://journals.biologists.com/jeb/article/26/4/354/13763/The-Kinetics-of-Locomotion-of-the-Grass-Snake
# Error processing URL 'https://doi.org/10.1002%2Fjmor.1051970204': 403 Client Error: Forbidden for url: https://onlinelibrary.wiley.com/doi/10.1002/jmor.1051970204
# Error processing URL 'https://doi.org/10.2307%2F1445288': 420 Client Error: Enhance Your Calm for url: https://www.jstor.org/stable/1445288?origin=crossref
# Error processing URL 'https://www.jstor.org/stable/1445288': 420 Client Error: Enhance Your Calm for url: https://www.jstor.org/stable/1445288
# Error processing URL 'https://doi.org/10.1242%2Fjeb.009050': 403 Client Error: Forbidden for url: https://journals.biologists.com/jeb/article/210/21/3862/17221/Effects-of-perch-diameter-and-incline-on-the
# Error processing URL 'https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6383867': 403 Client Error: Forbidden for url: https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6383867/
