# %%
import requests
from bs4 import BeautifulSoup, NavigableString, Comment
import re
from urllib.parse import urljoin
from IPython.display import display, HTML

# %%
def extract_text_from_dom(soup, class_name, elements=None):
    # Define a function to filter visible tags
    def tag_visible(element):
        if isinstance(element, Comment):
            return False
        if element.parent.name in ['style', 'script', 'head', 'title', 'meta', '[document]']:
            return False
        if class_name and class_name not in element.get('class', []):
            return False
        if elements and element.name not in elements:
            return False
        return True if isinstance(element, NavigableString) else tag_visible(element.parent)

    # Extract text from visible tags
    texts = soup.findAll(text=True)
    visible_texts = filter(tag_visible, texts)
    visible_text = u" ".join(t.strip() for t in visible_texts)

    # Split text into sentences using regular expressions
    sentences = re.split(r'(?<!\w\.\w.)(?<![A-Z][a-z]\.)(?<=\.|\?)\s', visible_text)
    return '\n'.join(sentences)

def extract_text_from_website(url, class_name=None, elements=None, visited_urls=None, max_depth=1):
    # initialize visited_urls as an empty set if its not provided
    if visited_urls is None:
        visited_urls = set()

    # check if the URL has been visited to avoid infinite recursion
    if url in visited_urls:
        return ""

    # add the current URL to visited URLs
    visited_urls.add(url)

    extracted_text = ""
    try:
        # fetch the webpage content
        response = requests.get(url)
        response.raise_for_status()

        # parse the HTML content
        soup = BeautifulSoup(response.content, 'html.parser')

        # extract text from the current page
        extracted_text = extract_text_from_dom(soup, class_name, elements)

        # find all links on the page
        links = soup.find_all('a', href=True, text=True)

        # extract text from linked pages recursively
        for link in links:
            subpage_url = link['href']
            # Convert relative links to absolute links
            subpage_url = urljoin(url, subpage_url)
            if subpage_url not in visited_urls: # and max_depth > 0
                extracted_text += extract_text_from_website(subpage_url, class_name, elements, visited_urls) #, max_depth - 1
                
    except Exception as e:
        print(f"Error processing URL '{url}': {e}")

    return extracted_text

def extract_text_to_file(url, file_path, visited_urls=None, max_depth=1):
    # init visited_urls as an empty set if its not provided
    if visited_urls is None:
        visited_urls = set()

    # check if the URL has been visited to avoid infinite recursion
    if url in visited_urls:
        return ""

    # ddd the current URL to visited URLs
    visited_urls.add(url)

    extracted_text = ""
    try:
        # fetch the webpage content
        response = requests.get(url)
        response.raise_for_status()

        # parse the HTML content
        soup = BeautifulSoup(response.content, 'html.parser')

        # extract text from the current page
        extracted_text = extract_text_from_dom(soup)

        # find all links on the page
        links = soup.find_all('a', href=True, text=True)

        # extract text from linked pages recursively
        for link in links:
            subpage_url = link['href']
            # convert relative links to absolute links
            subpage_url = urljoin(url, subpage_url)
            if subpage_url not in visited_urls: # and max_depth > 0
                extracted_text += extract_text_to_file(subpage_url, file_path, visited_urls) #, max_depth - 1

    except Exception as e:
        print(f"Error processing URL '{url}': {e}")

    return extracted_text


def display_text_in_new_tab(text):
    html_content = f"""
    <script type="text/javascript">
        var newWindow = window.open("", "_blank");
        newWindow.document.write(`<pre>{text}</pre>`);
        newWindow.document.close();
    </script>
    """
    display(HTML(html_content))

# %%
# Example usage
url = "https://en.wikipedia.org/wiki/Snake"
class_name = "group_content__20JQH elements_fontFamilyMontserrat__3GCpc"  # specify the class name
elements = ['p','h2','h3','h4']
extracted_text = extract_text_from_website(url)
display_text_in_new_tab(extracted_text)
file_path = "C:\\Users\\lukas\\OneDrive\\Desktop\\skola\\UKF\\bakalarka\\output\\outputEARTH.txt"
extract_text_to_file(url, file_path)
print(extracted_text)
# write the extracted_text to the file, had to use utf-8 for some characters
with open(file_path, 'w', encoding='utf-8') as f:
    f.write(extracted_text)
# Out:
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# C:\Users\lukas\anaconda3\lib\site-packages\bs4\builder\__init__.py:545: XMLParsedAsHTMLWarning: It looks like you're parsing an XML document using an HTML parser. If this really is an HTML document (maybe it's XHTML?), you can ignore or filter this warning. If it's XML, you should know that using an XML parser will be more reliable. To parse this document as XML, make sure you have the lxml package installed, and pass the keyword argument `features="xml"` into the BeautifulSoup constructor.
#   warnings.warn(
# Error processing URL 'https://opensource.org/programs#content': 429 Client Error: Too Many Requests for url: https://opensource.org/programs#content
# Error processing URL 'https://www.cdc.gov/spanish/az/a.html': 404 Client Error: Not Found for url: https://www.cdc.gov/spanish/az/a.html
# Error processing URL 'https://www.cdc.gov//search.cdc.gov/search/spanish/index.html#advanced': 404 Client Error: Not Found for url: https://www.cdc.gov//search.cdc.gov/search/spanish/index.html#advanced
# Error processing URL 'https://www.cdc.gov/az/a.html': 404 Client Error: Not Found for url: https://www.cdc.gov/az/a.html
# Error processing URL 'https://www.cdc.gov/az/b.html': 404 Client Error: Not Found for url: https://www.cdc.gov/az/b.html
# Error processing URL 'https://www.cdc.gov/az/c.html': 404 Client Error: Not Found for url: https://www.cdc.gov/az/c.html
# Error processing URL 'https://www.cdc.gov/az/d.html': 404 Client Error: Not Found for url: https://www.cdc.gov/az/d.html
# Error processing URL 'https://www.cdc.gov/az/e.html': 404 Client Error: Not Found for url: https://www.cdc.gov/az/e.html
# Error processing URL 'https://www.cdc.gov/az/f.html': 404 Client Error: Not Found for url: https://www.cdc.gov/az/f.html
# Error processing URL 'https://www.cdc.gov/az/g.html': 404 Client Error: Not Found for url: https://www.cdc.gov/az/g.html
# Error processing URL 'https://www.cdc.gov/az/h.html': 404 Client Error: Not Found for url: https://www.cdc.gov/az/h.html
# Error processing URL 'https://www.cdc.gov/az/i.html': 404 Client Error: Not Found for url: https://www.cdc.gov/az/i.html
# Error processing URL 'https://www.cdc.gov/az/j.html': 404 Client Error: Not Found for url: https://www.cdc.gov/az/j.html
# Error processing URL 'https://www.cdc.gov/az/k.html': 404 Client Error: Not Found for url: https://www.cdc.gov/az/k.html
# Error processing URL 'https://www.cdc.gov/az/l.html': 404 Client Error: Not Found for url: https://www.cdc.gov/az/l.html
# Error processing URL 'https://www.cdc.gov/az/m.html': 404 Client Error: Not Found for url: https://www.cdc.gov/az/m.html
# Error processing URL 'https://www.cdc.gov/az/n.html': 404 Client Error: Not Found for url: https://www.cdc.gov/az/n.html
# Error processing URL 'https://www.cdc.gov/az/o.html': 404 Client Error: Not Found for url: https://www.cdc.gov/az/o.html
# Error processing URL 'https://www.cdc.gov/az/p.html': 404 Client Error: Not Found for url: https://www.cdc.gov/az/p.html
# Error processing URL 'https://www.cdc.gov/az/q.html': 404 Client Error: Not Found for url: https://www.cdc.gov/az/q.html
# Error processing URL 'https://www.cdc.gov/az/r.html': 404 Client Error: Not Found for url: https://www.cdc.gov/az/r.html
# Error processing URL 'https://www.cdc.gov/az/s.html': 404 Client Error: Not Found for url: https://www.cdc.gov/az/s.html
# Error processing URL 'https://www.cdc.gov/az/t.html': 404 Client Error: Not Found for url: https://www.cdc.gov/az/t.html
# Error processing URL 'https://www.cdc.gov/az/u.html': 404 Client Error: Not Found for url: https://www.cdc.gov/az/u.html
# Error processing URL 'https://www.cdc.gov/az/v.html': 404 Client Error: Not Found for url: https://www.cdc.gov/az/v.html
# Error processing URL 'https://www.cdc.gov/az/w.html': 404 Client Error: Not Found for url: https://www.cdc.gov/az/w.html
# Error processing URL 'https://www.cdc.gov/az/x.html': 404 Client Error: Not Found for url: https://www.cdc.gov/az/x.html
# Error processing URL 'https://www.cdc.gov/az/y.html': 404 Client Error: Not Found for url: https://www.cdc.gov/az/y.html
# Error processing URL 'https://www.cdc.gov/az/z.html': 404 Client Error: Not Found for url: https://www.cdc.gov/az/z.html
# Error processing URL 'https://www.cdc.gov/az/0.html': 404 Client Error: Not Found for url: https://www.cdc.gov/az/0.html
# Error processing URL 'http://www.cdc.gov/ /health-topics.html': 404 Client Error: Not Found for url: https://www.cdc.gov/%20/health-topics.html
# Error processing URL 'https://intranet.cdc.gov/ncird/dbd/branches.html': ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# Error processing URL 'javascript:setupNavLinks('featured');': No connection adapters were found for "javascript:setupNavLinks('featured');"
# Error processing URL 'javascript:setupNavLinks('subscribe');': No connection adapters were found for "javascript:setupNavLinks('subscribe');"
# Error processing URL 'javascript:setupNavLinks('manage');': No connection adapters were found for "javascript:setupNavLinks('manage');"
# Error processing URL 'mailto:emailupdates@cdc.gov': No connection adapters were found for 'mailto:emailupdates@cdc.gov'
# Error processing URL 'mailto:subscriptions@cdc.gov': No connection adapters were found for 'mailto:subscriptions@cdc.gov'
# Error processing URL 'https://www.cdc.gov/DataStatistics/ /health-topics.html': 404 Client Error: Not Found for url: https://www.cdc.gov/DataStatistics/%20/health-topics.html
# Error processing URL 'https://www.cdc.gov/DataStatistics/ /datastatistics/index.html': 404 Client Error: Not Found for url: https://www.cdc.gov/DataStatistics/%20/datastatistics/index.html
# Error processing URL 'https://www.cdc.gov/publications/ /health-topics.html': 404 Client Error: Not Found for url: https://www.cdc.gov/publications/%20/health-topics.html
# Error processing URL 'https://www.cdc.gov/publications/ /datastatistics/index.html': 404 Client Error: Not Found for url: https://www.cdc.gov/publications/%20/datastatistics/index.html
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# Error processing URL 'https://github.com/en/site-policy': 404 Client Error: Not Found for url: https://github.com/en/site-policy
# Error processing URL 'https://github.com/en/site-policy/github-terms': 404 Client Error: Not Found for url: https://github.com/en/site-policy/github-terms
# Error processing URL 'https://github.com/en/site-policy/github-terms/github-terms-of-service': 404 Client Error: Not Found for url: https://github.com/en/site-policy/github-terms/github-terms-of-service
# Error processing URL 'https://github.com/en/site-policy/github-terms/github-corporate-terms-of-service': 404 Client Error: Not Found for url: https://github.com/en/site-policy/github-terms/github-corporate-terms-of-service
# Error processing URL 'https://github.com/en/site-policy/github-terms/github-terms-for-additional-products-and-features': 404 Client Error: Not Found for url: https://github.com/en/site-policy/github-terms/github-terms-for-additional-products-and-features
# Error processing URL 'https://github.com/en/site-policy/github-terms/github-community-guidelines': 404 Client Error: Not Found for url: https://github.com/en/site-policy/github-terms/github-community-guidelines
# Error processing URL 'https://github.com/en/site-policy/github-terms/github-community-code-of-conduct': 404 Client Error: Not Found for url: https://github.com/en/site-policy/github-terms/github-community-code-of-conduct
# Error processing URL 'https://github.com/en/site-policy/github-terms/github-pre-release-license-terms': 404 Client Error: Not Found for url: https://github.com/en/site-policy/github-terms/github-pre-release-license-terms
# Error processing URL 'https://github.com/en/site-policy/github-terms/github-sponsors-additional-terms': 404 Client Error: Not Found for url: https://github.com/en/site-policy/github-terms/github-sponsors-additional-terms
# Error processing URL 'https://github.com/en/site-policy/github-terms/github-registered-developer-agreement': 404 Client Error: Not Found for url: https://github.com/en/site-policy/github-terms/github-registered-developer-agreement
# Error processing URL 'https://github.com/en/site-policy/github-terms/github-marketplace-terms-of-service': 404 Client Error: Not Found for url: https://github.com/en/site-policy/github-terms/github-marketplace-terms-of-service
# Error processing URL 'https://github.com/en/site-policy/github-terms/github-marketplace-developer-agreement': 404 Client Error: Not Found for url: https://github.com/en/site-policy/github-terms/github-marketplace-developer-agreement
# Error processing URL 'https://github.com/en/site-policy/github-terms/github-research-program-terms': 404 Client Error: Not Found for url: https://github.com/en/site-policy/github-terms/github-research-program-terms
# Error processing URL 'https://github.com/en/site-policy/github-terms/github-open-source-applications-terms-and-conditions': 404 Client Error: Not Found for url: https://github.com/en/site-policy/github-terms/github-open-source-applications-terms-and-conditions
# Error processing URL 'https://github.com/en/site-policy/github-terms/github-event-terms': 404 Client Error: Not Found for url: https://github.com/en/site-policy/github-terms/github-event-terms
# Error processing URL 'https://github.com/en/site-policy/github-terms/github-event-code-of-conduct': 404 Client Error: Not Found for url: https://github.com/en/site-policy/github-terms/github-event-code-of-conduct
# Error processing URL 'https://github.com/en/site-policy/github-terms/github-educational-use-agreement': 404 Client Error: Not Found for url: https://github.com/en/site-policy/github-terms/github-educational-use-agreement
# Error processing URL 'https://github.com/en/site-policy/acceptable-use-policies/github-acceptable-use-policies': 404 Client Error: Not Found for url: https://github.com/en/site-policy/acceptable-use-policies/github-acceptable-use-policies
# Error processing URL 'https://github.com/en/site-policy/acceptable-use-policies/github-active-malware-or-exploits': 404 Client Error: Not Found for url: https://github.com/en/site-policy/acceptable-use-policies/github-active-malware-or-exploits
# Error processing URL 'https://github.com/en/site-policy/acceptable-use-policies/github-bullying-and-harassment': 404 Client Error: Not Found for url: https://github.com/en/site-policy/acceptable-use-policies/github-bullying-and-harassment
# Error processing URL 'https://github.com/en/site-policy/acceptable-use-policies/github-disrupting-the-experience-of-other-users': 404 Client Error: Not Found for url: https://github.com/en/site-policy/acceptable-use-policies/github-disrupting-the-experience-of-other-users
# Error processing URL 'https://github.com/en/site-policy/acceptable-use-policies/github-doxxing-and-invasion-of-privacy': 404 Client Error: Not Found for url: https://github.com/en/site-policy/acceptable-use-policies/github-doxxing-and-invasion-of-privacy
# Error processing URL 'https://github.com/en/site-policy/acceptable-use-policies/github-hate-speech-and-discrimination': 404 Client Error: Not Found for url: https://github.com/en/site-policy/acceptable-use-policies/github-hate-speech-and-discrimination
# Error processing URL 'https://github.com/en/site-policy/acceptable-use-policies/github-impersonation': 404 Client Error: Not Found for url: https://github.com/en/site-policy/acceptable-use-policies/github-impersonation
# Error processing URL 'https://github.com/en/site-policy/acceptable-use-policies/github-misinformation-and-disinformation': 404 Client Error: Not Found for url: https://github.com/en/site-policy/acceptable-use-policies/github-misinformation-and-disinformation
# Error processing URL 'https://github.com/en/site-policy/acceptable-use-policies/github-sexually-obscene-content': 404 Client Error: Not Found for url: https://github.com/en/site-policy/acceptable-use-policies/github-sexually-obscene-content
# Error processing URL 'https://github.com/en/site-policy/acceptable-use-policies/github-threats-of-violence-and-gratuitously-violent-content': 404 Client Error: Not Found for url: https://github.com/en/site-policy/acceptable-use-policies/github-threats-of-violence-and-gratuitously-violent-content
# Error processing URL 'https://github.com/en/site-policy/acceptable-use-policies/github-appeal-and-reinstatement': 404 Client Error: Not Found for url: https://github.com/en/site-policy/acceptable-use-policies/github-appeal-and-reinstatement
# Error processing URL 'https://github.com/en/site-policy/privacy-policies/github-general-privacy-statement': 404 Client Error: Not Found for url: https://github.com/en/site-policy/privacy-policies/github-general-privacy-statement
# Error processing URL 'https://github.com/en/site-policy/privacy-policies/github-subprocessors': 404 Client Error: Not Found for url: https://github.com/en/site-policy/privacy-policies/github-subprocessors
# Error processing URL 'https://github.com/en/site-policy/privacy-policies/github-cookies': 404 Client Error: Not Found for url: https://github.com/en/site-policy/privacy-policies/github-cookies
# Error processing URL 'https://github.com/en/site-policy/privacy-policies/github-codespaces-privacy-statement': 404 Client Error: Not Found for url: https://github.com/en/site-policy/privacy-policies/github-codespaces-privacy-statement
# Error processing URL 'https://github.com/en/site-policy/privacy-policies/github-candidate-privacy-policy': 404 Client Error: Not Found for url: https://github.com/en/site-policy/privacy-policies/github-candidate-privacy-policy
# Error processing URL 'https://github.com/en/site-policy/privacy-policies/github-octernships-terms-of-service': 404 Client Error: Not Found for url: https://github.com/en/site-policy/privacy-policies/github-octernships-terms-of-service
# Error processing URL 'https://github.com/en/site-policy/other-site-policies/github-and-trade-controls': 404 Client Error: Not Found for url: https://github.com/en/site-policy/other-site-policies/github-and-trade-controls
# Error processing URL 'https://github.com/en/site-policy/other-site-policies/github-deceased-user-policy': 404 Client Error: Not Found for url: https://github.com/en/site-policy/other-site-policies/github-deceased-user-policy
# Error processing URL 'https://github.com/en/site-policy/other-site-policies/github-logo-policy': 404 Client Error: Not Found for url: https://github.com/en/site-policy/other-site-policies/github-logo-policy
# Error processing URL 'https://github.com/en/site-policy/other-site-policies/github-government-takedown-policy': 404 Client Error: Not Found for url: https://github.com/en/site-policy/other-site-policies/github-government-takedown-policy
# Error processing URL 'https://github.com/en/site-policy/other-site-policies/github-username-policy': 404 Client Error: Not Found for url: https://github.com/en/site-policy/other-site-policies/github-username-policy
# Error processing URL 'https://github.com/en/site-policy/other-site-policies/guidelines-for-legal-requests-of-user-data': 404 Client Error: Not Found for url: https://github.com/en/site-policy/other-site-policies/guidelines-for-legal-requests-of-user-data
# Error processing URL 'https://github.com/en/site-policy/other-site-policies/github-account-recovery-policy': 404 Client Error: Not Found for url: https://github.com/en/site-policy/other-site-policies/github-account-recovery-policy
# Error processing URL 'https://github.com/en/site-policy/content-removal-policies/submitting-content-removal-requests': 404 Client Error: Not Found for url: https://github.com/en/site-policy/content-removal-policies/submitting-content-removal-requests
# Error processing URL 'https://github.com/en/site-policy/content-removal-policies/dmca-takedown-policy': 404 Client Error: Not Found for url: https://github.com/en/site-policy/content-removal-policies/dmca-takedown-policy
# Error processing URL 'https://github.com/en/site-policy/content-removal-policies/github-private-information-removal-policy': 404 Client Error: Not Found for url: https://github.com/en/site-policy/content-removal-policies/github-private-information-removal-policy
# Error processing URL 'https://github.com/en/site-policy/content-removal-policies/github-trademark-policy': 404 Client Error: Not Found for url: https://github.com/en/site-policy/content-removal-policies/github-trademark-policy
# Error processing URL 'https://github.com/en/site-policy/content-removal-policies/guide-to-submitting-a-dmca-counter-notice': 404 Client Error: Not Found for url: https://github.com/en/site-policy/content-removal-policies/guide-to-submitting-a-dmca-counter-notice
# Error processing URL 'https://github.com/en/site-policy/content-removal-policies/guide-to-submitting-a-dmca-takedown-notice': 404 Client Error: Not Found for url: https://github.com/en/site-policy/content-removal-policies/guide-to-submitting-a-dmca-takedown-notice
# Error processing URL 'https://github.com/en/site-policy/security-policies/coordinated-disclosure-of-security-vulnerabilities': 404 Client Error: Not Found for url: https://github.com/en/site-policy/security-policies/coordinated-disclosure-of-security-vulnerabilities
# Error processing URL 'https://github.com/en/site-policy/security-policies/github-bug-bounty-program-legal-safe-harbor': 404 Client Error: Not Found for url: https://github.com/en/site-policy/security-policies/github-bug-bounty-program-legal-safe-harbor
# Error processing URL 'https://github.com/en/site-policy/security-policies/github-sirt-description-rfc-2350': 404 Client Error: Not Found for url: https://github.com/en/site-policy/security-policies/github-sirt-description-rfc-2350
# Error processing URL 'https://github.com/en/site-policy/github-company-policies/github-statement-against-modern-slavery-and-child-labor': 404 Client Error: Not Found for url: https://github.com/en/site-policy/github-company-policies/github-statement-against-modern-slavery-and-child-labor
# Error processing URL 'https://github.com/en/site-policy/github-company-policies/github-anti-bribery-statement': 404 Client Error: Not Found for url: https://github.com/en/site-policy/github-company-policies/github-anti-bribery-statement
# Error processing URL 'https://github.com/en/site-policy/github-company-policies/github-gpl-cooperation-commitment': 404 Client Error: Not Found for url: https://github.com/en/site-policy/github-company-policies/github-gpl-cooperation-commitment
# Error processing URL 'https://github.com/en/site-policy/github-company-policies/github-gifts-and-entertainment-policy': 404 Client Error: Not Found for url: https://github.com/en/site-policy/github-company-policies/github-gifts-and-entertainment-policy
# Error processing URL 'https://github.com/en/site-policy/privacy-policies': 404 Client Error: Not Found for url: https://github.com/en/site-policy/privacy-policies
# Error processing URL 'javascript:void(0)': No connection adapters were found for 'javascript:void(0)'
# Error processing URL 'https://account.microsoft.com/privacy': ('Connection aborted.', TimeoutError(10060, 'A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond', None, 10060, None))
